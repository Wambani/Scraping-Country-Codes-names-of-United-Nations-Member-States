# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = ('http://www.fao.org/countryprofiles/iso3list/en/')
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Getting the title of the page
title = soup.title
print(title)
# Out:
# <title>Country codes/names | FAO | Food and Agriculture Organization of the United Nations</title>

# %%
content = soup.find(id="c460959")

# %%
# content

# %%
headers = content.find_all('th')
headers
# Out:
# [<th>Short name</th>,
#  <th>Official name</th>,
#  <th>ISO3</th>,
#  <th>ISO2</th>,
#  <th>UNI</th>,
#  <th>UNDP</th>,
#  <th>FAOSTAT</th>,
#  <th>GAUL</th>]

# %%
shortName = content.find_all('a')

# %%
shortName[:10]
# Out:
# [<a href="http://www.fao.org/countryprofiles/index/en/?iso3=AFG" target="_self">Afghanistan</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=ALB" target="_self">Albania</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=DZA" target="_self">Algeria</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=AND" target="_self">Andorra</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=AGO" target="_self">Angola</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=ATG" target="_self">Antigua and Barbuda</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=ARG" target="_self">Argentina</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=ARM" target="_self">Armenia</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=AUS" target="_self">Australia</a>,
#  <a href="http://www.fao.org/countryprofiles/index/en/?iso3=AUT" target="_self">Austria</a>]

# %%
type(shortName[0])
# Out:
# bs4.element.Tag

# %%
countries = []
for line in shortName:
    country = line.get_text()
    countries.append(country)
print(countries[:10])
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria']

# %%
officialName = content.find_all(class_="official")

# %%
officialName[:10]
# Out:
# [<td class="official" id="countryNameLabelAFG">the Islamic Republic of Afghanistan</td>,
#  <td class="official" id="countryNameLabelALB">the Republic of Albania</td>,
#  <td class="official" id="countryNameLabelDZA">the People's Democratic Republic of Algeria</td>,
#  <td class="official" id="countryNameLabelAND">the Principality of Andorra</td>,
#  <td class="official" id="countryNameLabelAGO">the Republic of Angola</td>,
#  <td class="official" id="countryNameLabelATG">Antigua and Barbuda</td>,
#  <td class="official" id="countryNameLabelARG">the Argentine Republic</td>,
#  <td class="official" id="countryNameLabelARM">the Republic of Armenia</td>,
#  <td class="official" id="countryNameLabelAUS">Australia</td>,
#  <td class="official" id="countryNameLabelAUT">the Republic of Austria</td>]

# %%
type(officialName[-1])
# Out:
# bs4.element.Tag

# %%
OfficialNames = []
for line in officialName:
    nation = line.get_text()
    OfficialNames.append(nation)

# %%
print(OfficialNames[:10])
# Out:
# ['the Islamic Republic of Afghanistan', 'the Republic of Albania', "the People's Democratic Republic of Algeria", 'the Principality of Andorra', 'the Republic of Angola', 'Antigua and Barbuda', 'the Argentine Republic', 'the Republic of Armenia', 'Australia', 'the Republic of Austria']

# %%
iso3 = content.find_all(class_="iso3")

# %%
iso3[0]
# Out:
# <td class="iso3" id="iso3LabelAFG">AFG</td>

# %%
ISO3 = []
for line in iso3:
    i = line.get_text()
    ISO3.append(i)

# %%
ISO3[:10]
# Out:
# ['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'AUS', 'AUT']

# %%
iso = content.find_all(class_='iso2')

# %%
ISO2 = []
for line in iso3:
    i = line.get_text()
    ISO2.append(i)

# %%
ISO2[:10]
# Out:
# ['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'AUS', 'AUT']

# %%
uni = content.find_all(class_="uni")

# %%
uni[:10]
# Out:
# [<td class="uni" id="unLabelAFG">4</td>,
#  <td class="uni" id="unLabelALB">8</td>,
#  <td class="uni" id="unLabelDZA">12</td>,
#  <td class="uni" id="unLabelAND">20</td>,
#  <td class="uni" id="unLabelAGO">24</td>,
#  <td class="uni" id="unLabelATG">28</td>,
#  <td class="uni" id="unLabelARG">32</td>,
#  <td class="uni" id="unLabelARM">51</td>,
#  <td class="uni" id="unLabelAUS">36</td>,
#  <td class="uni" id="unLabelAUT">40</td>]

# %%
UNI = []
for line in uni:
    i = line.get_text()
    UNI.append(i)

# %%
UNI[:10]
# Out:
# ['4', '8', '12', '20', '24', '28', '32', '51', '36', '40']

# %%
undp = content.find_all(class_="undp")

# %%
undp[:10]
# Out:
# [<td class="undp" id="undpLabelAFG">AFG</td>,
#  <td class="undp" id="undpLabelALB">ALB</td>,
#  <td class="undp" id="undpLabelDZA">DZA</td>,
#  <td class="undp" id="undpLabelAND">AND</td>,
#  <td class="undp" id="undpLabelAGO">AGO</td>,
#  <td class="undp" id="undpLabelATG">ATG</td>,
#  <td class="undp" id="undpLabelARG">ARG</td>,
#  <td class="undp" id="undpLabelARM">ARM</td>,
#  <td class="undp" id="undpLabelAUS">AUS</td>,
#  <td class="undp" id="undpLabelAUT">AUT</td>]

# %%
UNDP = []
for line in undp:
    i = line.get_text()
    UNDP.append(i)

# %%
UNDP[:10]
# Out:
# ['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'AUS', 'AUT']

# %%
faostat = content.find_all(class_="faostat")

# %%
FAOSTAT = []
for line in faostat:
    i = line.get_text()
    FAOSTAT.append(i)

# %%
FAOSTAT[:10]
# Out:
# ['2', '3', '4', '6', '7', '8', '9', '1', '10', '11']

# %%
gaul = content.find_all(class_="gaul")

# %%
GAUL = []
for line in gaul:
    i = line.get_text()
    GAUL.append(i)

# %%
GAUL[:10]
# Out:
# ['1', '3', '4', '7', '8', '11', '12', '13', '17', '18']

# %%
#  [OfficialNames, ISO3, ISO2, UNI, UNDP,FAOSTAT, GAUL]

# %%
lists_ = [[countries, OfficialNames, ISO3, ISO2, UNI, UNDP,FAOSTAT, GAUL]]

# %%
# u = pd.concat(lists_)

# %%
framesList = []
for value in lists_:
    df = pd.DataFrame(value)
    framesList.append(df)

# %%
# framesList

# %%
df = pd.concat(framesList)

# %%
df.head()
# Out:
#                                    0                        1    \
# 0                          Afghanistan                  Albania
# 1  the Islamic Republic of Afghanistan  the Republic of Albania
# 2                                  AFG                      ALB
# 3                                  AFG                      ALB
# 4                                    4                        8
#
#                                            2                            3    \
# 0                                      Algeria                      Andorra
# 1  the People's Democratic Republic of Algeria  the Principality of Andorra
# 2                                          DZA                          AND
# 3                                          DZA                          AND
# 4                                           12                           20
#
#                       4                    5                       6    \
# 0                  Angola  Antigua and Barbuda               Argentina
# 1  the Republic of Angola  Antigua and Barbuda  the Argentine Republic
# 2                     AGO                  ATG                     ARG
# 3                     AGO                  ATG                     ARG
# 4                      24                   28                      32
#
#                        7          8                        9    \
# 0                  Armenia  Australia                  Austria
# 1  the Republic of Armenia  Australia  the Republic of Austria
# 2                      ARM        AUS                      AUT
# 3                      ARM        AUS                      AUT
# 4                       51         36                       40
#
#              ...                                         186  \
# 0            ...                 United Republic of Tanzania
# 1            ...             the United Republic of Tanzania
# 2            ...                                         TZA
# 3            ...                                         TZA
# 4            ...                                         834
#
#                             187                              188  \
# 0      United States of America                          Uruguay
# 1  the United States of America  the Eastern Republic of Uruguay
# 2                           USA                              URY
# 3                           USA                              URY
# 4                           840                              858
#
#                           189                      190  \
# 0                  Uzbekistan                  Vanuatu
# 1  the Republic of Uzbekistan  the Republic of Vanuatu
# 2                         UZB                      VUT
# 3                         UZB                      VUT
# 4                         860                      548
#
#                                     191                                 192  \
# 0    Venezuela (Bolivarian Republic of)                            Viet Nam
# 1  the Bolivarian Republic of Venezuela  the Socialist Republic of Viet Nam
# 2                                   VEN                                 VNM
# 3                                   VEN                                 VNM
# 4                                   862                                 704
#
#                      193                     194                       195
# 0                  Yemen                  Zambia                  Zimbabwe
# 1  the Republic of Yemen  the Republic of Zambia  the Republic of Zimbabwe
# 2                    YEM                     ZMB                       ZWE
# 3                    YEM                     ZMB                       ZWE
# 4                    887                     894                       716
#
# [5 rows x 196 columns]

# %%
len(df)
# Out:
# 8

# %%
df = df.transpose()

# %%
df.head()
# Out:
#              0                                            1    2    3   4  \
# 0  Afghanistan          the Islamic Republic of Afghanistan  AFG  AFG   4
# 1      Albania                      the Republic of Albania  ALB  ALB   8
# 2      Algeria  the People's Democratic Republic of Algeria  DZA  DZA  12
# 3      Andorra                  the Principality of Andorra  AND  AND  20
# 4       Angola                       the Republic of Angola  AGO  AGO  24
#
#      5  6  7
# 0  AFG  2  1
# 1  ALB  3  3
# 2  DZA  4  4
# 3  AND  6  7
# 4  AGO  7  8

# %%
df.columns = ['Short Name', 'Official name', 'ISO3', 'ISO2', 'UNI','UNDP', 'FAOSTAT', 'GAUL']

# %%
df.head()
# Out:
#     Short Name                                Official name ISO3 ISO2 UNI  \
# 0  Afghanistan          the Islamic Republic of Afghanistan  AFG  AFG   4
# 1      Albania                      the Republic of Albania  ALB  ALB   8
# 2      Algeria  the People's Democratic Republic of Algeria  DZA  DZA  12
# 3      Andorra                  the Principality of Andorra  AND  AND  20
# 4       Angola                       the Republic of Angola  AGO  AGO  24
#
#   UNDP FAOSTAT GAUL
# 0  AFG       2    1
# 1  ALB       3    3
# 2  DZA       4    4
# 3  AND       6    7
# 4  AGO       7    8

# %%
df
# Out:
#                                             Short Name  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                              Andorra
# 4                                               Angola
# 5                                  Antigua and Barbuda
# 6                                            Argentina
# 7                                              Armenia
# 8                                            Australia
# 9                                              Austria
# 10                                          Azerbaijan
# 11                                             Bahamas
# 12                                             Bahrain
# 13                                          Bangladesh
# 14                                            Barbados
# 15                                             Belarus
# 16                                             Belgium
# 17                                              Belize
# 18                                               Benin
# 19                                              Bhutan
# 20                    Bolivia (Plurinational State of)
# 21                              Bosnia and Herzegovina
# 22                                            Botswana
# 23                                              Brazil
# 24                                   Brunei Darussalam
# 25                                            Bulgaria
# 26                                        Burkina Faso
# 27                                             Burundi
# 28                                          Cabo Verde
# 29                                            Cambodia
# ..                                                 ...
# 166                                              Sudan
# 167                                           Suriname
# 168                                             Sweden
# 169                                        Switzerland
# 170                               Syrian Arab Republic
# 171                                         Tajikistan
# 172                                           Thailand
# 173                                        Timor-Leste
# 174                                               Togo
# 175                                           Tokelau
# 176                                              Tonga
# 177                                Trinidad and Tobago
# 178                                            Tunisia
# 179                                             Turkey
# 180                                       Turkmenistan
# 181                                             Tuvalu
# 182                                             Uganda
# 183                                            Ukraine
# 184                               United Arab Emirates
# 185  United Kingdom of Great Britain and Northern I...
# 186                        United Republic of Tanzania
# 187                           United States of America
# 188                                            Uruguay
# 189                                         Uzbekistan
# 190                                            Vanuatu
# 191                 Venezuela (Bolivarian Republic of)
# 192                                           Viet Nam
# 193                                              Yemen
# 194                                             Zambia
# 195                                           Zimbabwe
#
#                                          Official name ISO3 ISO2  UNI UNDP  \
# 0                  the Islamic Republic of Afghanistan  AFG  AFG    4  AFG
# 1                              the Republic of Albania  ALB  ALB    8  ALB
# 2          the People's Democratic Republic of Algeria  DZA  DZA   12  DZA
# 3                          the Principality of Andorra  AND  AND   20  AND
# 4                               the Republic of Angola  AGO  AGO   24  AGO
# 5                                  Antigua and Barbuda  ATG  ATG   28  ATG
# 6                               the Argentine Republic  ARG  ARG   32  ARG
# 7                              the Republic of Armenia  ARM  ARM   51  ARM
# 8                                            Australia  AUS  AUS   36  AUS
# 9                              the Republic of Austria  AUT  AUT   40  AUT
# 10                          the Republic of Azerbaijan  AZE  AZE   31  AZE
# 11                     the Commonwealth of the Bahamas  BHS  BHS   44  BHS
# 12                              the Kingdom of Bahrain  BHR  BHR   48  BHR
# 13                 the People's Republic of Bangladesh  BGD  BGD   50  BGD
# 14                                            Barbados  BRB  BRB   52  BRB
# 15                             the Republic of Belarus  BLR  BLR  112  BLR
# 16                              the Kingdom of Belgium  BEL  BEL   56  BEL
# 17                                              Belize  BLZ  BLZ   84  BLZ
# 18                               the Republic of Benin  BEN  BEN  204  BEN
# 19                               the Kingdom of Bhutan  BTN  BTN   64  BTN
# 20                  the Plurinational State of Bolivia  BOL  BOL   68  BOL
# 21                              Bosnia and Herzegovina  BIH  BIH   70  BIH
# 22                            the Republic of Botswana  BWA  BWA   72  BWA
# 23                   the Federative Republic of Brazil  BRA  BRA   76  BRA
# 24                                   Brunei Darussalam  BRN  BRN   96  BRN
# 25                            the Republic of Bulgaria  BGR  BGR  100  BGR
# 26                                        Burkina Faso  BFA  BFA  854  BFA
# 27                             the Republic of Burundi  BDI  BDI  108  BDI
# 28                              Republic of Cabo Verde  CPV  CPV  132  CPV
# 29                             the Kingdom of Cambodia  KHM  KHM  116  KHM
# ..                                                 ...  ...  ...  ...  ...
# 166                          the Republic of the Sudan  SDN  SDN  736  SDN
# 167                           the Republic of Suriname  SUR  SUR  740  SUR
# 168                              the Kingdom of Sweden  SWE  SWE  752  SWE
# 169                            the Swiss Confederation  CHE  CHE  756  CHE
# 170                           the Syrian Arab Republic  SYR  SYR  760  SYR
# 171                         the Republic of Tajikistan  TJK  TJK  762  TJK
# 172                            the Kingdom of Thailand  THA  THA  764  THA
# 173             the Democratic Republic of Timor-Leste  TLS  TLS  626  TLS
# 174                              the Togolese Republic  TGO  TGO  768  TGO
# 175                                            Tokelau  TKL  TKL  772  TKL
# 176                               the Kingdom of Tonga  TON  TON  776  TON
# 177                the Republic of Trinidad and Tobago  TTO  TTO  780  TTO
# 178                            the Republic of Tunisia  TUN  TUN  788  TUN
# 179                             the Republic of Turkey  TUR  TUR  792  TUR
# 180                                       Turkmenistan  TKM  TKM  795  TKM
# 181                                             Tuvalu  TUV  TUV  798  TUV
# 182                             the Republic of Uganda  UGA  UGA  800  UGA
# 183                                            Ukraine  UKR  UKR  804  UKR
# 184                           the United Arab Emirates  ARE  ARE  784  ARE
# 185  the United Kingdom of Great Britain and Northe...  GBR  GBR  826  GBR
# 186                    the United Republic of Tanzania  TZA  TZA  834  TZA
# 187                       the United States of America  USA  USA  840  USA
# 188                    the Eastern Republic of Uruguay  URY  URY  858  URY
# 189                         the Republic of Uzbekistan  UZB  UZB  860  UZB
# 190                            the Republic of Vanuatu  VUT  VUT  548  VUT
# 191               the Bolivarian Republic of Venezuela  VEN  VEN  862  VEN
# 192                 the Socialist Republic of Viet Nam  VNM  VNM  704  VNM
# 193                              the Republic of Yemen  YEM  YEM  887  YEM
# 194                             the Republic of Zambia  ZMB  ZMB  894  ZMB
# 195                           the Republic of Zimbabwe  ZWE  ZWE  716  ZWE
#
#     FAOSTAT   GAUL
# 0         2      1
# 1         3      3
# 2         4      4
# 3         6      7
# 4         7      8
# 5         8     11
# 6         9     12
# 7         1     13
# 8        10     17
# 9        11     18
# 10       52     19
# 11       12     20
# 12       13     21
# 13       16     23
# 14       14     24
# 15       57     26
# 16      255     27
# 17       23     28
# 18       53     29
# 19       18     31
# 20       19     33
# 21       80     34
# 22       20     35
# 23       21     37
# 24       26     40
# 25       27     41
# 26      233     42
# 27       29     43
# 28       35     47
# 29      115     44
# ..      ...    ...
# 166     276  40764
# 167     207    233
# 168     210    236
# 169     211    237
# 170     212    238
# 171     208    239
# 172     216    240
# 173     176    242
# 174     217    243
# 175     218    244
# 176     219    245
# 177     220    246
# 178     222    248
# 179     223    249
# 180     213    250
# 181     227    252
# 182     226    253
# 183     230    254
# 184     225    255
# 185     229    256
# 186     215    257
# 187     231    259
# 188     234    260
# 189     235    261
# 190     155    262
# 191     236    263
# 192     237    264
# 193     249    269
# 194     251    270
# 195     181    271
#
# [196 rows x 8 columns]
